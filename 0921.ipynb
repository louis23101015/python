# %%
import pandas as pd
import plotly

df = pd.read_csv("202501_202507_주민등록인구및세대현황_월간.csv", encoding='cp949')
df
# Out:
#                           행정구역 2025년01월_총인구수 2025년01월_세대수  2025년01월_세대당 인구  \
# 0          서울특별시  (1100000000)     9,330,658    4,482,949             2.08
# 1       서울특별시 종로구 (1111000000)       138,208       72,156             1.92
# 2        서울특별시 중구 (1114000000)       120,325       64,933             1.85
# 3       서울특별시 용산구 (1117000000)       203,727      103,204             1.97
# 4       서울특별시 성동구 (1120000000)       273,549      131,857             2.07
# ..                         ...           ...          ...              ...
# 287      경상남도 거창군 (4888000000)        59,514       31,098             1.91
# 288      경상남도 합천군 (4889000000)        40,133       23,668             1.70
# 289      제주특별자치도  (5000000000)       669,460      314,683             2.13
# 290   제주특별자치도 제주시 (5011000000)       487,623      225,733             2.16
# 291  제주특별자치도 서귀포시 (5013000000)       181,837       88,950             2.04
#
#     2025년01월_남자 인구수 2025년01월_여자 인구수  2025년01월_남여 비율 2025년02월_총인구수  \
# ...
